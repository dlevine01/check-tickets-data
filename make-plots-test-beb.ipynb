# %%
# imports

import pandas as pd
import altair as alt

from datetime import date

# read in data

today = date.today()
this_month = today.strftime('%m')

previous_month_total = pd.read_csv('data/' + this_month + ' - previous month - total.csv')
previous_previous_total = pd.read_csv('data/' + this_month + ' - previous previous - total.csv')

previous_month_by_type = pd.read_csv('data/' + this_month + ' - previous month - by type.csv')
previous_previous_by_type = pd.read_csv('data/' + this_month + ' - previous previous - by type.csv')

previous_month_by_agency = pd.read_csv('data/' + this_month + ' - previous month - by agency.csv')
previous_previous_by_agency = pd.read_csv('data/' + this_month + ' - previous previous - by agency.csv')

# %%
previous_month_total
# Out:
#    Unnamed: 0  Total
# 0  2023-05-01     13
# 1  2023-05-02     13
# 2  2023-05-03     13
# 3  2023-05-04     13
# 4  2023-05-05     13

# %%
previous_month_total = pd.read_csv('data/' + this_month + ' - previous month - total.csv', index_col=0)

# %%
previous_month_total
# Out:
#             Total
# 2023-05-01     13
# 2023-05-02     13
# 2023-05-03     13
# 2023-05-04     13
# 2023-05-05     13

# %%
previous_month_total.index = previous_month_total.index.rename('date')

# %%
previous_month_total
# Out:
#             Total
# date
# 2023-05-01     13
# 2023-05-02     13
# 2023-05-03     13
# 2023-05-04     13
# 2023-05-05     13

# %%
previous_month_total['month'] = 'previous'

# %%
previous_month_total.melt(id_vars='date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3650'>3651</a> try:
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3651'>3652</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3652'>3653</a> except KeyError as err:
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 previous_month_total.melt(id_vars='date')
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py:8985, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8974'>8975</a> @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8975'>8976</a> def melt(
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8976'>8977</a>     self,
#    (...)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8982'>8983</a>     ignore_index: bool = True,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8983'>8984</a> ) -> DataFrame:
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8984'>8985</a>     return melt(
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8985'>8986</a>         self,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8986'>8987</a>         id_vars=id_vars,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8987'>8988</a>         value_vars=value_vars,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8988'>8989</a>         var_name=var_name,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8989'>8990</a>         value_name=value_name,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8990'>8991</a>         col_level=col_level,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8991'>8992</a>         ignore_index=ignore_index,
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=8992'>8993</a>     ).__finalize__(self, method="melt")
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py:128, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py?line=125'>126</a> mdata: dict[Hashable, AnyArrayLike] = {}
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py?line=126'>127</a> for col in id_vars:
# --> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py?line=127'>128</a>     id_data = frame.pop(col)
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py?line=128'>129</a>     if is_extension_array_dtype(id_data):
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/reshape/melt.py?line=129'>130</a>         if K > 0:
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py:5553, in DataFrame.pop(self, item)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5511'>5512</a> def pop(self, item: Hashable) -> Series:
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5512'>5513</a>     """
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5513'>5514</a>     Return item and drop from frame. Raise KeyError if not found.
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5514'>5515</a>
#    (...)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5550'>5551</a>     3  monkey        NaN
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5551'>5552</a>     """
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=5552'>5553</a>     return super().pop(item=item)
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py:853, in NDFrame.pop(self, item)
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py?line=851'>852</a> def pop(self, item: Hashable) -> Series | Any:
# --> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py?line=852'>853</a>     result = self[item]
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py?line=853'>854</a>     del self[item]
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py?line=855'>856</a>     return result
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=3758'>3759</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=3759'>3760</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=3760'>3761</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=3761'>3762</a> if is_integer(indexer):
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py?line=3762'>3763</a>     indexer = [indexer]
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3651'>3652</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3652'>3653</a> except KeyError as err:
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3653'>3654</a>     raise KeyError(key) from err
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3654'>3655</a> except TypeError:
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3655'>3656</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3656'>3657</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3657'>3658</a>     #  the TypeError.
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py?line=3658'>3659</a>     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
previous_month_total.reset_index().melt(id_vars='date')
# Out:
#          date variable     value
# 0  2023-05-01    Total        13
# 1  2023-05-02    Total        13
# 2  2023-05-03    Total        13
# 3  2023-05-04    Total        13
# 4  2023-05-05    Total        13
# 5  2023-05-01    month  previous
# 6  2023-05-02    month  previous
# 7  2023-05-03    month  previous
# 8  2023-05-04    month  previous
# 9  2023-05-05    month  previous

# %%
previous_month_total = pd.read_csv('data/' + this_month + ' - previous month - total.csv')

# %%
pd.concat([previous_month_total,previous_previous_total])
# Out:
#    Unnamed: 0    Total
# 0  2023-05-01       13
# 1  2023-05-02       13
# 2  2023-05-03       13
# 3  2023-05-04       13
# 4  2023-05-05       13
# 0  2023-05-01  1291893
# 1  2023-05-02  1291893
# 2  2023-05-03  1291893
# 3  2023-05-04  1291893
# 4  2023-05-05  1291893

# %%
previous_month_total.columns = ['date loaded','previous month total']

# %%
previous_previous_total.columns = ['date loaded','previous previous total']

# %%
pd.concat([previous_month_total,previous_previous_total])
# Out:
#   date loaded  previous month total  previous previous total
# 0  2023-05-01                  13.0                      NaN
# 1  2023-05-02                  13.0                      NaN
# 2  2023-05-03                  13.0                      NaN
# 3  2023-05-04                  13.0                      NaN
# 4  2023-05-05                  13.0                      NaN
# 0  2023-05-01                   NaN                1291893.0
# 1  2023-05-02                   NaN                1291893.0
# 2  2023-05-03                   NaN                1291893.0
# 3  2023-05-04                   NaN                1291893.0
# 4  2023-05-05                   NaN                1291893.0

# %%
previous_month_total.melt(id_vars='date loaded')
# Out:
#   date loaded              variable  value
# 0  2023-05-01  previous month total     13
# 1  2023-05-02  previous month total     13
# 2  2023-05-03  previous month total     13
# 3  2023-05-04  previous month total     13
# 4  2023-05-05  previous month total     13

# %%
pd.concat([
    previous_month_total.melt(id_vars='date loaded'),
    previous_previous_total.melt(id_vars='date loaded')
])
# Out:
#   date loaded                 variable    value
# 0  2023-05-01     previous month total       13
# 1  2023-05-02     previous month total       13
# 2  2023-05-03     previous month total       13
# 3  2023-05-04     previous month total       13
# 4  2023-05-05     previous month total       13
# 0  2023-05-01  previous previous total  1291893
# 1  2023-05-02  previous previous total  1291893
# 2  2023-05-03  previous previous total  1291893
# 3  2023-05-04  previous previous total  1291893
# 4  2023-05-05  previous previous total  1291893

# %%
total_tidy = pd.concat([
    previous_month_total.melt(id_vars='date loaded'),
    previous_previous_total.melt(id_vars='date loaded')
])

# %%
(
    alt.Chart(total_tidy)
    .mark_point()
    .encode(
        x='date loaded',
        y='value',
        color='variable'
    )
)
# Out:
# alt.Chart(...)

# %%
total_tidy = (
    pd.concat([
        previous_month_total.melt(id_vars='date loaded'),
        previous_previous_total.melt(id_vars='date loaded')
    ])
    .rename(columns={
        'variable':'month',
        'value':'data loaded'
    })
)

# %%
previous_month_total.columns = ['date checked','previous month total']

# %%
previous_previous_total.columns = ['date checked','previous previous total']

# %%
total_tidy = (
    pd.concat([
        previous_month_total.melt(id_vars='date checked'),
        previous_previous_total.melt(id_vars='date checked')
    ])
    .rename(columns={
        'variable':'data month',
        'value':'rows loaded'
    })
)

# %%
(
    alt.Chart(total_tidy)
    .mark_point()
    .encode(
        x='date checked',
        y='rows loaded',
        color='data month'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(total_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='data month'
    )
)
# Out:
# alt.Chart(...)

# %%
previous_month_by_agency
# Out:
#    Unnamed: 0  PORT AUTHORITY  TRIBOROUGH BRIDGE AND TUNNEL POLICE  CON RAIL
# 0  2023-05-01             NaN                                  NaN       NaN  \
# 1  2023-05-02             NaN                                  NaN       NaN
# 2  2023-05-03             NaN                                  NaN       NaN
# 3  2023-05-04             NaN                                  NaN       NaN
# 4  2023-05-05             NaN                                  NaN       NaN
#
#    DEPARTMENT OF BUSINESS SERVICES  BOARD OF ESTIMATE  FIRE DEPARTMENT
# 0                              NaN                NaN              NaN  \
# 1                              NaN                NaN              NaN
# 2                              NaN                NaN              NaN
# 3                              NaN                NaN              NaN
# 4                              NaN                NaN              NaN
#
#    TAXI AND LIMOUSINE COMMISSION  HOUSING AUTHORITY
# 0                            NaN                NaN  \
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
#
#    STATEN ISLAND RAPID TRANSIT POLICE  ...  HEALTH AND HOSPITAL CORP. POLICE
# 0                                 NaN  ...                               NaN  \
# 1                                 NaN  ...                               NaN
# 2                                 NaN  ...                               NaN
# 3                                 NaN  ...                               NaN
# 4                                 NaN  ...                               NaN
#
#    METRO NORTH RAILROAD POLICE  NYS OFFICE OF MENTAL HEALTH POLICE  O M R D D
# 0                          NaN                                 NaN        NaN  \
# 1                          NaN                                 NaN        NaN
# 2                          NaN                                 NaN        NaN
# 3                          NaN                                 NaN        NaN
# 4                          NaN                                 NaN        NaN
#
#    ROOSEVELT ISLAND SECURITY  SEA GATE ASSOCIATION POLICE
# 0                        NaN                          NaN  \
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#    SNUG HARBOR CULTURAL CENTER RANGERS  WATERFRONT COMMISSION OF NY HARBOR
# 0                                  NaN                                 NaN  \
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#    SUNY MARITIME COLLEGE  NYC OFFICE OF THE SHERIFF
# 0                    NaN                        NaN
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
# [5 rows x 35 columns]

# %%
previous_month_by_agency = previous_month_by_agency.rename(columns={'Unnamed: 0': 'date checked'})

# %%
previous_previous_by_agency = previous_previous_by_agency.rename(columns={'Unnamed: 0': 'date checked'})

# %%
previous_previous_by_agency
# Out:
#   date checked  PORT AUTHORITY  TRIBOROUGH BRIDGE AND TUNNEL POLICE  CON RAIL
# 0   2023-05-01             137                                    1        56  \
# 1   2023-05-02             137                                    1        56
# 2   2023-05-03             137                                    1        56
# 3   2023-05-04             137                                    1        56
# 4   2023-05-05             137                                    1        56
#
#    DEPARTMENT OF BUSINESS SERVICES  BOARD OF ESTIMATE  FIRE DEPARTMENT
# 0                              NaN                NaN               68  \
# 1                              NaN                NaN               68
# 2                              NaN                NaN               68
# 3                              NaN                NaN               68
# 4                              NaN                NaN               68
#
#    TAXI AND LIMOUSINE COMMISSION  HOUSING AUTHORITY
# 0                              2                NaN  \
# 1                              2                NaN
# 2                              2                NaN
# 3                              2                NaN
# 4                              2                NaN
#
#    STATEN ISLAND RAPID TRANSIT POLICE  ...  HEALTH AND HOSPITAL CORP. POLICE
# 0                                 NaN  ...                               191  \
# 1                                 NaN  ...                               191
# 2                                 NaN  ...                               191
# 3                                 NaN  ...                               191
# 4                                 NaN  ...                               191
#
#    METRO NORTH RAILROAD POLICE  NYS OFFICE OF MENTAL HEALTH POLICE  O M R D D
# 0                          NaN                                   3        NaN  \
# 1                          NaN                                   3        NaN
# 2                          NaN                                   3        NaN
# 3                          NaN                                   3        NaN
# 4                          NaN                                   3        NaN
#
#    ROOSEVELT ISLAND SECURITY  SEA GATE ASSOCIATION POLICE
# 0                        215                          NaN  \
# 1                        215                          NaN
# 2                        215                          NaN
# 3                        215                          NaN
# 4                        215                          NaN
#
#    SNUG HARBOR CULTURAL CENTER RANGERS  WATERFRONT COMMISSION OF NY HARBOR
# 0                                  NaN                                 NaN  \
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#    SUNY MARITIME COLLEGE  NYC OFFICE OF THE SHERIFF
# 0                    NaN                        190
# 1                    NaN                        190
# 2                    NaN                        190
# 3                    NaN                        190
# 4                    NaN                        190
#
# [5 rows x 35 columns]

# %%
previous_previous_by_agency['data month'] = 'previous previous'

# %%
previous_previous_by_agency.melt(id_vars=['date checked','data month'])
# Out:
#     date checked         data month                   variable  value
# 0     2023-05-01  previous previous             PORT AUTHORITY  137.0
# 1     2023-05-02  previous previous             PORT AUTHORITY  137.0
# 2     2023-05-03  previous previous             PORT AUTHORITY  137.0
# 3     2023-05-04  previous previous             PORT AUTHORITY  137.0
# 4     2023-05-05  previous previous             PORT AUTHORITY  137.0
# ..           ...                ...                        ...    ...
# 165   2023-05-01  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 166   2023-05-02  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 167   2023-05-03  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 168   2023-05-04  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 169   2023-05-05  previous previous  NYC OFFICE OF THE SHERIFF  190.0
#
# [170 rows x 4 columns]

# %%
previous_month_by_agency['data month'] = 'previous month'

# %%
by_agency_tidy = (
    pd.concat([
        previous_month_by_agency.melt(id_vars=['date checked','data month']),
        previous_previous_by_agency.melt(id_vars=['date checked','data month'])
    ])
)

# %%
by_agency_tidy
# Out:
#     date checked         data month                   variable  value
# 0     2023-05-01     previous month             PORT AUTHORITY    NaN
# 1     2023-05-02     previous month             PORT AUTHORITY    NaN
# 2     2023-05-03     previous month             PORT AUTHORITY    NaN
# 3     2023-05-04     previous month             PORT AUTHORITY    NaN
# 4     2023-05-05     previous month             PORT AUTHORITY    NaN
# ..           ...                ...                        ...    ...
# 165   2023-05-01  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 166   2023-05-02  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 167   2023-05-03  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 168   2023-05-04  previous previous  NYC OFFICE OF THE SHERIFF  190.0
# 169   2023-05-05  previous previous  NYC OFFICE OF THE SHERIFF  190.0
#
# [340 rows x 4 columns]

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='value',
        color='variable'
    )
)
# Out:
# alt.Chart(...)

# %%
by_agency_tidy = (
    pd.concat([
        previous_month_by_agency.melt(id_vars=['date checked','data month']),
        previous_previous_by_agency.melt(id_vars=['date checked','data month'])
    ])
        .rename(columns={
        'variable':'Agency',
        'value':'rows loaded'
    })
)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='data month',
        shape='Agency'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_point()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month'
    )
)
# Out:
# alt.Chart(...)

# %%
previous_previous_tidy = (
    previous_previous_by_agency
    .melt(
        id_vars=['date checked','data month'],
        var_name='Agency',
        value_name='rows loaded'
    )
)

# %%
(
    alt.Chart(previous_previous_tidy)
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency'
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        tooltip=['Agency']
    )
)
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_line()
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        tooltip=['Agency']
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_circle(size=50)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        tooltip=['Agency']
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(previous_previous_tidy.dropna())
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        tooltip=['Agency']
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month']
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
by_agency_tidy.dtypes
# Out:
# date checked     object
# data month       object
# Agency           object
# rows loaded     float64
# dtype: object

# %%
by_agency_tidy['date checked'] = pd.to_datetime(by_agency_tidy['date checked'])

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month']
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
by_agency_tidy
# Out:
#     date checked         data month                     Agency  rows loaded
# 0     2023-05-01     previous month             PORT AUTHORITY          NaN
# 1     2023-05-02     previous month             PORT AUTHORITY          NaN
# 2     2023-05-03     previous month             PORT AUTHORITY          NaN
# 3     2023-05-04     previous month             PORT AUTHORITY          NaN
# 4     2023-05-05     previous month             PORT AUTHORITY          NaN
# ..           ...                ...                        ...          ...
# 165   2023-05-01  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 166   2023-05-02  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 167   2023-05-03  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 168   2023-05-04  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 169   2023-05-05  previous previous  NYC OFFICE OF THE SHERIFF        190.0
#
# [340 rows x 4 columns]

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='data month'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked:O',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked(date):O',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='monthdate(date checked):O',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        alt.X('monthdate(date checked):O'),
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        alt.X('date checked').axis(tickMinStep=2),
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        alt.X('date checked').axis(tickMinStep=24),
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        alt.X('date checked').axis(ticks=False),
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='date checked'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='data month'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='data month'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='data month'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
by_agency_tidy
# Out:
#     date checked         data month                     Agency  rows loaded
# 0     2023-05-01     previous month             PORT AUTHORITY          NaN
# 1     2023-05-02     previous month             PORT AUTHORITY          NaN
# 2     2023-05-03     previous month             PORT AUTHORITY          NaN
# 3     2023-05-04     previous month             PORT AUTHORITY          NaN
# 4     2023-05-05     previous month             PORT AUTHORITY          NaN
# ..           ...                ...                        ...          ...
# 165   2023-05-01  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 166   2023-05-02  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 167   2023-05-03  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 168   2023-05-04  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 169   2023-05-05  previous previous  NYC OFFICE OF THE SHERIFF        190.0
#
# [340 rows x 4 columns]

# %%
base = (
    alt.Chart(by_agency_tidy)
    .encode(
        x='Agency',
        y='rows loaded'
    )
)

point = (
    base
    .mark_point(filled=True)
    .encode(
        alt.Color("data month"),
        size=alt.value(100)
    )
)

line = (
    base
    .mark_line()
    .encode(
        detail="Agency",
    )
)

line + point
# Out:
# alt.LayerChart(...)

# %%
by_agency_tidy
# Out:
#     date checked         data month                     Agency  rows loaded
# 0     2023-05-01     previous month             PORT AUTHORITY          NaN
# 1     2023-05-02     previous month             PORT AUTHORITY          NaN
# 2     2023-05-03     previous month             PORT AUTHORITY          NaN
# 3     2023-05-04     previous month             PORT AUTHORITY          NaN
# 4     2023-05-05     previous month             PORT AUTHORITY          NaN
# ..           ...                ...                        ...          ...
# 165   2023-05-01  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 166   2023-05-02  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 167   2023-05-03  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 168   2023-05-04  previous previous  NYC OFFICE OF THE SHERIFF        190.0
# 169   2023-05-05  previous previous  NYC OFFICE OF THE SHERIFF        190.0
#
# [340 rows x 4 columns]

# %%
by_agency_tidy[
    (by_agency_tidy['data month'] == 'previous month') &
    (by_agency_tidy['rows loaded'].notna())

]
# Out:
#    date checked      data month             Agency  rows loaded
# 75   2023-05-01  previous month  POLICE DEPARTMENT         13.0
# 76   2023-05-02  previous month  POLICE DEPARTMENT         13.0
# 77   2023-05-03  previous month  POLICE DEPARTMENT         13.0
# 78   2023-05-04  previous month  POLICE DEPARTMENT         13.0
# 79   2023-05-05  previous month  POLICE DEPARTMENT         13.0

# %%
base = (
    alt.Chart(by_agency_tidy.sort_values(by='rows loaded', ascending=False))
    .encode(
        x='Agency',
        y='rows loaded'
    )
)

point = (
    base
    .mark_point(filled=True)
    .encode(
        alt.Color("data month"),
        size=alt.value(100)
    )
)

line = (
    base
    .mark_line()
    .encode(
        detail="Agency",
    )
)

line + point
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        x='Agency',
        y='rows loaded'
    )
)

point = (
    base
    .mark_point(filled=True)
    .encode(
        alt.Color("data month"),
        size=alt.value(100)
    )
)

line = (
    base
    .mark_line()
    .encode(
        detail="Agency",
    )
)

line + point
# Out:
# alt.LayerChart(...)

# %%
(
    alt.Chart(by_agency_tidy)
    .mark_line(point=True)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency',
        shape='data month',
        tooltip=['Agency','data month'],
        order='data month'
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        y='Agency',
        x='rows loaded'
    )
)

target_point = (
    base
    .mark_point(shape='diamond')
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
)

progress_tick = (
    base
    .mark_tick()
    .encode(
        color="date checked",
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        y='Agency',
        x='rows loaded'
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        color="date checked",
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        y='Agency',
        x='rows loaded'
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy)
    .encode(
        alt.Y('Agency', sort='x'),
        x='rows loaded',
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy)
    .encode(
        alt.Y('Agency', sort='-x'),
        x='rows loaded',
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.Y('Agency', sort='-x'),
        x='rows loaded',
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
previous_previous_by_agency
# Out:
#   date checked  PORT AUTHORITY  TRIBOROUGH BRIDGE AND TUNNEL POLICE  CON RAIL
# 0   2023-05-01             137                                    1        56  \
# 1   2023-05-02             137                                    1        56
# 2   2023-05-03             137                                    1        56
# 3   2023-05-04             137                                    1        56
# 4   2023-05-05             137                                    1        56
#
#    DEPARTMENT OF BUSINESS SERVICES  BOARD OF ESTIMATE  FIRE DEPARTMENT
# 0                              NaN                NaN               68  \
# 1                              NaN                NaN               68
# 2                              NaN                NaN               68
# 3                              NaN                NaN               68
# 4                              NaN                NaN               68
#
#    TAXI AND LIMOUSINE COMMISSION  HOUSING AUTHORITY
# 0                              2                NaN  \
# 1                              2                NaN
# 2                              2                NaN
# 3                              2                NaN
# 4                              2                NaN
#
#    STATEN ISLAND RAPID TRANSIT POLICE  ...  METRO NORTH RAILROAD POLICE
# 0                                 NaN  ...                          NaN  \
# 1                                 NaN  ...                          NaN
# 2                                 NaN  ...                          NaN
# 3                                 NaN  ...                          NaN
# 4                                 NaN  ...                          NaN
#
#    NYS OFFICE OF MENTAL HEALTH POLICE  O M R D D  ROOSEVELT ISLAND SECURITY
# 0                                   3        NaN                        215  \
# 1                                   3        NaN                        215
# 2                                   3        NaN                        215
# 3                                   3        NaN                        215
# 4                                   3        NaN                        215
#
#    SEA GATE ASSOCIATION POLICE  SNUG HARBOR CULTURAL CENTER RANGERS
# 0                          NaN                                  NaN  \
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                          NaN                                  NaN
#
#    WATERFRONT COMMISSION OF NY HARBOR  SUNY MARITIME COLLEGE
# 0                                 NaN                    NaN  \
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#    NYC OFFICE OF THE SHERIFF         data month
# 0                        190  previous previous
# 1                        190  previous previous
# 2                        190  previous previous
# 3                        190  previous previous
# 4                        190  previous previous
#
# [5 rows x 36 columns]

# %%
previous_previous_by_agency.iloc[-1,1:]
# Out:
# PORT AUTHORITY                                       137
# TRIBOROUGH BRIDGE AND TUNNEL POLICE                    1
# CON RAIL                                              56
# DEPARTMENT OF BUSINESS SERVICES                      NaN
# BOARD OF ESTIMATE                                    NaN
# FIRE DEPARTMENT                                       68
# TAXI AND LIMOUSINE COMMISSION                          2
# HOUSING AUTHORITY                                    NaN
# STATEN ISLAND RAPID TRANSIT POLICE                   NaN
# AMTRAK RAILROAD POLICE                                 2
# PARKS DEPARTMENT                                     284
# LONG ISLAND RAILROAD                                 184
# TRANSIT AUTHORITY                                    337
# NYS PARKS POLICE                                       2
# NYS COURT OFFICERS                                    90
# POLICE DEPARTMENT                                  13034
# DEPARTMENT OF CORRECTION                               8
# NYC TRANSIT AUTHORITY MANAGERS                        26
# DEPARTMENT OF SANITATION                           51551
# TRAFFIC                                           758079
# PARKING CONTROL UNIT                                 NaN
# DEPARTMENT OF TRANSPORTATION                      467271
# HEALTH DEPARTMENT POLICE                               7
# OTHER/UNKNOWN AGENCIES                                23
# HEALTH AND HOSPITAL CORP. POLICE                     191
# METRO NORTH RAILROAD POLICE                          NaN
# NYS OFFICE OF MENTAL HEALTH POLICE                     3
# O M R D D                                            NaN
# ROOSEVELT ISLAND SECURITY                            215
# SEA GATE ASSOCIATION POLICE                          NaN
# SNUG HARBOR CULTURAL CENTER RANGERS                  NaN
# WATERFRONT COMMISSION OF NY HARBOR                   NaN
# SUNY MARITIME COLLEGE                                NaN
# NYC OFFICE OF THE SHERIFF                            190
# data month                             previous previous
# Name: 4, dtype: object

# %%
previous_previous_by_agency.iloc[-1,1:].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 previous_previous_by_agency.iloc[-1,1:].sort_values(ascending=False)
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py:3630, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py?line=3627'>3628</a> # GH 35922. Make sorting stable by leveraging nargsort
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py?line=3628'>3629</a> values_to_sort = ensure_key_mapped(self, key)._values if key else self._values
# -> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py?line=3629'>3630</a> sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py?line=3631'>3632</a> if is_range_indexer(sorted_index, len(sorted_index)):
#    <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/series.py?line=3632'>3633</a>     if inplace:
#
# File ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py:429, in nargsort(items, kind, ascending, na_position, key, mask)
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py?line=426'>427</a>     non_nans = non_nans[::-1]
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py?line=427'>428</a>     non_nan_idx = non_nan_idx[::-1]
# --> <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py?line=428'>429</a> indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py?line=429'>430</a> if not ascending:
#     <a href='file:///Users/Dan/Documents/comptroller%20projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/sorting.py?line=430'>431</a>     indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'str'

# %%
previous_previous_by_agency.iloc[-1,1:].sort_values(by='previous previous', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 previous_previous_by_agency.iloc[-1,1:].sort_values(by='previous previous', ascending=False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
previous_previous_by_agency.iloc[-1,1:]
# Out:
# PORT AUTHORITY                                       137
# TRIBOROUGH BRIDGE AND TUNNEL POLICE                    1
# CON RAIL                                              56
# DEPARTMENT OF BUSINESS SERVICES                      NaN
# BOARD OF ESTIMATE                                    NaN
# FIRE DEPARTMENT                                       68
# TAXI AND LIMOUSINE COMMISSION                          2
# HOUSING AUTHORITY                                    NaN
# STATEN ISLAND RAPID TRANSIT POLICE                   NaN
# AMTRAK RAILROAD POLICE                                 2
# PARKS DEPARTMENT                                     284
# LONG ISLAND RAILROAD                                 184
# TRANSIT AUTHORITY                                    337
# NYS PARKS POLICE                                       2
# NYS COURT OFFICERS                                    90
# POLICE DEPARTMENT                                  13034
# DEPARTMENT OF CORRECTION                               8
# NYC TRANSIT AUTHORITY MANAGERS                        26
# DEPARTMENT OF SANITATION                           51551
# TRAFFIC                                           758079
# PARKING CONTROL UNIT                                 NaN
# DEPARTMENT OF TRANSPORTATION                      467271
# HEALTH DEPARTMENT POLICE                               7
# OTHER/UNKNOWN AGENCIES                                23
# HEALTH AND HOSPITAL CORP. POLICE                     191
# METRO NORTH RAILROAD POLICE                          NaN
# NYS OFFICE OF MENTAL HEALTH POLICE                     3
# O M R D D                                            NaN
# ROOSEVELT ISLAND SECURITY                            215
# SEA GATE ASSOCIATION POLICE                          NaN
# SNUG HARBOR CULTURAL CENTER RANGERS                  NaN
# WATERFRONT COMMISSION OF NY HARBOR                   NaN
# SUNY MARITIME COLLEGE                                NaN
# NYC OFFICE OF THE SHERIFF                            190
# data month                             previous previous
# Name: 4, dtype: object

# %%
by_agency_tidy[
    (by_agency_tidy['data month']=='previous previous') &
    (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
]
# Out:
#     date checked         data month                               Agency
# 4     2023-05-05  previous previous                       PORT AUTHORITY  \
# 9     2023-05-05  previous previous  TRIBOROUGH BRIDGE AND TUNNEL POLICE
# 14    2023-05-05  previous previous                             CON RAIL
# 19    2023-05-05  previous previous      DEPARTMENT OF BUSINESS SERVICES
# 24    2023-05-05  previous previous                    BOARD OF ESTIMATE
# 29    2023-05-05  previous previous                      FIRE DEPARTMENT
# 34    2023-05-05  previous previous        TAXI AND LIMOUSINE COMMISSION
# 39    2023-05-05  previous previous                    HOUSING AUTHORITY
# 44    2023-05-05  previous previous   STATEN ISLAND RAPID TRANSIT POLICE
# 49    2023-05-05  previous previous               AMTRAK RAILROAD POLICE
# 54    2023-05-05  previous previous                     PARKS DEPARTMENT
# 59    2023-05-05  previous previous                 LONG ISLAND RAILROAD
# 64    2023-05-05  previous previous                    TRANSIT AUTHORITY
# 69    2023-05-05  previous previous                     NYS PARKS POLICE
# 74    2023-05-05  previous previous                   NYS COURT OFFICERS
# 79    2023-05-05  previous previous                    POLICE DEPARTMENT
# 84    2023-05-05  previous previous             DEPARTMENT OF CORRECTION
# 89    2023-05-05  previous previous       NYC TRANSIT AUTHORITY MANAGERS
# 94    2023-05-05  previous previous             DEPARTMENT OF SANITATION
# 99    2023-05-05  previous previous                              TRAFFIC
# 104   2023-05-05  previous previous                 PARKING CONTROL UNIT
# 109   2023-05-05  previous previous         DEPARTMENT OF TRANSPORTATION
# 114   2023-05-05  previous previous             HEALTH DEPARTMENT POLICE
# 119   2023-05-05  previous previous               OTHER/UNKNOWN AGENCIES
# 124   2023-05-05  previous previous     HEALTH AND HOSPITAL CORP. POLICE
# 129   2023-05-05  previous previous          METRO NORTH RAILROAD POLICE
# 134   2023-05-05  previous previous   NYS OFFICE OF MENTAL HEALTH POLICE
# 139   2023-05-05  previous previous                            O M R D D
# 144   2023-05-05  previous previous            ROOSEVELT ISLAND SECURITY
# 149   2023-05-05  previous previous          SEA GATE ASSOCIATION POLICE
# 154   2023-05-05  previous previous  SNUG HARBOR CULTURAL CENTER RANGERS
# 159   2023-05-05  previous previous   WATERFRONT COMMISSION OF NY HARBOR
# 164   2023-05-05  previous previous                SUNY MARITIME COLLEGE
# 169   2023-05-05  previous previous            NYC OFFICE OF THE SHERIFF
#
#      rows loaded
# 4          137.0
# 9            1.0
# 14          56.0
# 19           NaN
# 24           NaN
# 29          68.0
# 34           2.0
# 39           NaN
# 44           NaN
# 49           2.0
# 54         284.0
# 59         184.0
# 64         337.0
# 69           2.0
# 74          90.0
# 79       13034.0
# 84           8.0
# 89          26.0
# 94       51551.0
# 99      758079.0
# 104          NaN
# 109     467271.0
# 114          7.0
# 119         23.0
# 124        191.0
# 129          NaN
# 134          3.0
# 139          NaN
# 144        215.0
# 149          NaN
# 154          NaN
# 159          NaN
# 164          NaN
# 169        190.0

# %%
(
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows_loaded', ascending=False)
    ['Agency']
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-ce3f358c7f40> in ?()
#       2     by_agency_tidy[
#       3         (by_agency_tidy['data month']=='previous previous') &
#       4         (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
#       5     ]
# ----> 6     .sort_values('rows_loaded', ascending=False)
#       7     ['Agency']
#       8 )
#
# ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6764         elif len(by):
#    6765             # len(by) == 1
#    6766
#    6767             by = by[0]
# -> 6768             k = self._get_label_or_level_values(by, axis=axis)
#    6769
#    6770             # need to rewrap column in Series to apply key function
#    6771             if key is not None:
#
# ~/Documents/comptroller projects/check-tickets-data/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1774             values = self.xs(key, axis=other_axes[0])._values
#    1775         elif self._is_level_reference(key, axis=axis):
#    1776             values = self.axes[axis].get_level_values(key)._values
#    1777         else:
# -> 1778             raise KeyError(key)
#    1779
#    1780         # Check for duplicates
#    1781         if values.ndim > 1:
#
# KeyError: 'rows_loaded'

# %%
(
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
)
# Out:
# 99                                 TRAFFIC
# 109           DEPARTMENT OF TRANSPORTATION
# 94                DEPARTMENT OF SANITATION
# 79                       POLICE DEPARTMENT
# 64                       TRANSIT AUTHORITY
# 54                        PARKS DEPARTMENT
# 144              ROOSEVELT ISLAND SECURITY
# 124       HEALTH AND HOSPITAL CORP. POLICE
# 169              NYC OFFICE OF THE SHERIFF
# 59                    LONG ISLAND RAILROAD
# 4                           PORT AUTHORITY
# 74                      NYS COURT OFFICERS
# 29                         FIRE DEPARTMENT
# 14                                CON RAIL
# 89          NYC TRANSIT AUTHORITY MANAGERS
# 119                 OTHER/UNKNOWN AGENCIES
# 84                DEPARTMENT OF CORRECTION
# 114               HEALTH DEPARTMENT POLICE
# 134     NYS OFFICE OF MENTAL HEALTH POLICE
# 69                        NYS PARKS POLICE
# 49                  AMTRAK RAILROAD POLICE
# 34           TAXI AND LIMOUSINE COMMISSION
# 9      TRIBOROUGH BRIDGE AND TUNNEL POLICE
# 19         DEPARTMENT OF BUSINESS SERVICES
# 24                       BOARD OF ESTIMATE
# 39                       HOUSING AUTHORITY
# 44      STATEN ISLAND RAPID TRANSIT POLICE
# 104                   PARKING CONTROL UNIT
# 129            METRO NORTH RAILROAD POLICE
# 139                              O M R D D
# 149            SEA GATE ASSOCIATION POLICE
# 154    SNUG HARBOR CULTURAL CENTER RANGERS
# 159     WATERFRONT COMMISSION OF NY HARBOR
# 164                  SUNY MARITIME COLLEGE
# Name: Agency, dtype: object

# %%
(
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
    .to_list()
)
# Out:
# ['TRAFFIC',
#  'DEPARTMENT OF TRANSPORTATION',
#  'DEPARTMENT OF SANITATION',
#  'POLICE DEPARTMENT',
#  'TRANSIT AUTHORITY',
#  'PARKS DEPARTMENT',
#  'ROOSEVELT ISLAND SECURITY',
#  'HEALTH AND HOSPITAL CORP. POLICE',
#  'NYC OFFICE OF THE SHERIFF',
#  'LONG ISLAND RAILROAD',
#  'PORT AUTHORITY',
#  'NYS COURT OFFICERS',
#  'FIRE DEPARTMENT',
#  'CON RAIL',
#  'NYC TRANSIT AUTHORITY MANAGERS',
#  'OTHER/UNKNOWN AGENCIES',
#  'DEPARTMENT OF CORRECTION',
#  'HEALTH DEPARTMENT POLICE',
#  'NYS OFFICE OF MENTAL HEALTH POLICE',
#  'NYS PARKS POLICE',
#  'AMTRAK RAILROAD POLICE',
#  'TAXI AND LIMOUSINE COMMISSION',
#  'TRIBOROUGH BRIDGE AND TUNNEL POLICE',
#  'DEPARTMENT OF BUSINESS SERVICES',
#  'BOARD OF ESTIMATE',
#  'HOUSING AUTHORITY',
#  'STATEN ISLAND RAPID TRANSIT POLICE',
#  'PARKING CONTROL UNIT',
#  'METRO NORTH RAILROAD POLICE',
#  'O M R D D',
#  'SEA GATE ASSOCIATION POLICE',
#  'SNUG HARBOR CULTURAL CENTER RANGERS',
#  'WATERFRONT COMMISSION OF NY HARBOR',
#  'SUNY MARITIME COLLEGE']

# %%
ordering = (
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
    .to_list()
)

# %%
base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.Y('Agency', sort=ordering),
        x='rows loaded',
    )
)

target_point = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

target_point + progress_tick
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy)
    .encode(
        x='date checked',
        y='rows loaded',
        color='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

previous_month_timeline + previous_previous_timeline
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy)
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy)
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy)
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point()
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point()
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(strokeWidth=1)
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=True,
        )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(color='none'),
        )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(color='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=100, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Y('rows loaded',scale=dict(domainMin=0)),
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=100, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='Agency',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(point=True)
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=100, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive(bind_y=False)
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        y='rows loaded',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive(bind_y=False)
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        alt.Y('rows loaded', scale=alt.Scale(domain=[0, 1_000_000]),
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive(bind_y=False)
# Out:
#   Cell In[128], line 1
#     timeline_base = (
#                     ^
# SyntaxError: '(' was never closed

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        alt.Y('rows loaded', scale=alt.Scale(domain=[0, 1_000_000])),
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive(bind_y=False)
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        alt.Y('rows loaded', scale=alt.Scale(domain=[0, 1_000_000])),
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        y='rows loaded',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

(previous_month_timeline + previous_previous_timeline).interactive()
# Out:
# alt.LayerChart(...)

# %%
# reformat to tidy and concat
# build plots

# totals

previous_month_total.columns = ['date checked','previous month total']
previous_previous_total.columns = ['date checked','previous previous total']

total_tidy = (
    pd.concat([
        previous_month_total.melt(id_vars='date checked'),
        previous_previous_total.melt(id_vars='date checked')
    ])
    .rename(columns={
        'variable':'data month',
        'value':'rows loaded'
    })
)

total_plot = (
    alt.Chart(total_tidy)
    .mark_point()
    .encode(
        x='date checked',
        y='rows loaded',
        color='data month'
    )
)


# by type


# by agency


previous_month_by_agency['data month'] = 'previous month'
previous_previous_by_agency['data month'] = 'previous previous'

by_agency_tidy = (
    pd.concat([
        previous_month_by_agency.melt(id_vars=['date checked','data month']),
        previous_previous_by_agency.melt(id_vars=['date checked','data month'])
    ])
    .rename(columns={
        'variable':'Agency',
        'value':'rows loaded'
    })
)

by_agency_tidy['date checked'] = pd.to_datetime(by_agency_tidy['date checked'])


ordering = (
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
    .to_list()
)

## timeline

timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        y='rows loaded',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

timeline = (previous_month_timeline + previous_previous_timeline).interactive()


## progress bars

progress_bars_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.Y('Agency', sort=ordering),
        x='rows loaded',
        tooltip='Agency'
    )
)

target_point = (
    progress_bars_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    progress_bars_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

agency_progress_plot = (target_point + progress_tick).interactive()

# save to html

# %%
alt.vconcat(total_plot, timeline, agency_progress_plot)
# Out:
# alt.VConcatChart(...)

# %%
# reformat to tidy and concat
# build plots

# totals

previous_month_total.columns = ['date checked','previous month total']
previous_previous_total.columns = ['date checked','previous previous total']

total_tidy = (
    pd.concat([
        previous_month_total.melt(id_vars='date checked'),
        previous_previous_total.melt(id_vars='date checked')
    ])
    .rename(columns={
        'variable':'data month',
        'value':'rows loaded'
    })
)

total_plot = (
    alt.Chart(total_tidy)
    .mark_point()
    .encode(
        x='date checked',
        y='rows loaded',
        color='data month'
    )
)


# by type


# by agency


previous_month_by_agency['data month'] = 'previous month'
previous_previous_by_agency['data month'] = 'previous previous'

by_agency_tidy = (
    pd.concat([
        previous_month_by_agency.melt(id_vars=['date checked','data month']),
        previous_previous_by_agency.melt(id_vars=['date checked','data month'])
    ])
    .rename(columns={
        'variable':'Agency',
        'value':'rows loaded'
    })
)

by_agency_tidy['date checked'] = pd.to_datetime(by_agency_tidy['date checked'])


ordering = (
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
    .to_list()
)

## timeline

timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        y='rows loaded',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

agency_timeline = (previous_month_timeline + previous_previous_timeline).interactive()


## progress bars

progress_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.Y('Agency', sort=ordering),
        x='rows loaded',
        tooltip='Agency'
    )
)

target_point = (
    progress_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    progress_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

agency_progress_plot = (target_point + progress_tick).interactive(bind_x=False)

# save to html

# %%
alt.vconcat(total_plot, timeline, agency_progress_plot)
# Out:
# alt.VConcatChart(...)

# %%
total_plot
# Out:
# alt.Chart(...)

# %%
# reformat to tidy and concat
# build plots

# totals

previous_month_total.columns = ['date checked','previous month total']
previous_previous_total.columns = ['date checked','previous previous total']

total_tidy = (
    pd.concat([
        previous_month_total.melt(id_vars='date checked'),
        previous_previous_total.melt(id_vars='date checked')
    ])
    .rename(columns={
        'variable':'data month',
        'value':'rows loaded'
    })
)

total_plot = (
    alt.Chart(total_tidy)
    .mark_point()
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        y='rows loaded',
        color='data month'
    )
)


# by type


# by agency


previous_month_by_agency['data month'] = 'previous month'
previous_previous_by_agency['data month'] = 'previous previous'

by_agency_tidy = (
    pd.concat([
        previous_month_by_agency.melt(id_vars=['date checked','data month']),
        previous_previous_by_agency.melt(id_vars=['date checked','data month'])
    ])
    .rename(columns={
        'variable':'Agency',
        'value':'rows loaded'
    })
)

by_agency_tidy['date checked'] = pd.to_datetime(by_agency_tidy['date checked'])


ordering = (
    by_agency_tidy[
        (by_agency_tidy['data month']=='previous previous') &
        (by_agency_tidy['date checked']==by_agency_tidy['date checked'].max())
    ]
    .sort_values('rows loaded', ascending=False)
    ['Agency']
    .to_list()
)

## timeline

timeline_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.X('monthdate(date checked):O').title('date checked'),
        alt.Color('Agency', sort=ordering),
        y='rows loaded',
        tooltip='Agency'
    )
)

previous_month_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')
    )
    .mark_line(
        point=alt.OverlayMarkDef(size=200, fill='null')
    )
)

previous_previous_timeline = (
    timeline_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_line(
        strokeWidth=1, 
        point=alt.OverlayMarkDef(size=200, fill='null'),
    )
)

agency_timeline = (previous_month_timeline + previous_previous_timeline).interactive()


## progress bars

progress_base = (
    alt.Chart(by_agency_tidy.dropna())
    .encode(
        alt.Y('Agency', sort=ordering),
        x='rows loaded',
        tooltip='Agency'
    )
)

target_point = (
    progress_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous previous')
    )
    .mark_point(shape='diamond')
)

progress_tick = (
    progress_base
    .transform_filter(
        alt.FieldEqualPredicate(field='data month', equal='previous month')

    )
    .mark_tick()
    .encode(
        alt.Color('monthdate(date checked):O').title('date checked'),
    )
)

agency_progress_plot = (target_point + progress_tick).interactive(bind_x=False)

# save to html

# %%
total_plot
# Out:
# alt.Chart(...)

# %%
alt.vconcat(total_plot, timeline, agency_progress_plot)
# Out:
# alt.VConcatChart(...)

# %%
total_plot.save('plots/total_plot.svg')

# %%
agency_timeline.save('plots/agency_timeline.svg')
# Out:
# WARN Scale bindings are currently only supported for scales with unbinned, continuous domains.

# %%
agency_progress_plot.save('plots/agency_progress.svg')
# Out:
# WARN Scale bindings are currently only supported for scales with unbinned, continuous domains.

# %%
agency_progress_plot.save('plots/agency_progress.json')

# %%
agency_timeline.save('plots/agency_timeline.json')

# %%
total_plot.save('plots/total_plot.json')
